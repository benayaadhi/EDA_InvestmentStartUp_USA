# %% [markdown]
# ## EDA by Group JAB (Jo,Arif,Benaya)
# data from https://www.kaggle.com/arindam235/startup-investments-crunchbase?select=investments_VC.csv

# %% [markdown]
# ### 1. Data Dictionary

# %% [markdown]
# permalink = untuk cek di website crunchbase.com/...
#
# name = nama perusahaan
#
# homepage_url = link website perusahaan
#
# category_list = categori dari perusahaanya
#
# market = target bidang yang disasar
#
# funding_total_usd = total pendanaan dalam bentuk USD
#
# status = status dari perusahaan itu
#
# country_code = code negara
#
# state_code = code kota dari suatu negara
#
# region = provinsi
#
# city = new york
#
# funding_rounds =
#
# founded_at = tahun berdirinya perusahaan(tgl,bulan,tahun)
#
# founded_month = tahun berdirinya perusahan(bulan, tahun)
#
# founded_quarter = tahun berdirinya perusahaan(quarter,tahun)
#
# founded_year = tahun berdirinya perusahaan(tahun)
#
# first_funding = penghimpunan dana awal
#
# last_funding = penghimpunan dana akhir
#
# seed = pendanaan awal yang didapat dari investor eksternal
#
# venture= modal dalam bentuk uang yang diberikan kepada startup yang potensial dan sedang berkembang.
#
# equity_crowdfunding= pendanaan secara urun dana
#
# undisclosed= dana yg dirahasiakan dan ga dimasukan di dokumen publik
#
# convertible_note : jenis obligasi yang dapat dikonversikan menjadi saham dari perusahaan penerbit obligasi dan biasanya pada rasio pertukaran yang sudah ditentukan terlebih dahulu pada penerbitan obligasi tersebut.
#
# debt_financing: dana pinjaman yang harus dikembalikan
#
# angel = pendanaan putaran ini diberikan oleh investor individu
#
# grant = pendanaan secara sukarela dari investor(misal memenangkan suatu lomba)
#
# private_equity = perusahaan yang mengumpulkan dana dari pihak-pihak terbatas untuk diinvestasikan diinstrumen
# yg tidak publikasikan
#
# post_ipo_equity = ini ada jika perusahaan sudah go public dan melakukan invest
#
# post_ipo_debt = firms meminjamkan dana ke perusahaan setelah perusahaan itu go public.
#
# secondary_market = pasar keuangan yang digunakan untuk memperdagangkan sekuriti yang telah diterbitkan dalam penawaran umum perdana.
#
# product_crowdfunding = metode untuk meningkatkan modal melalui usaha kolektif yang berasal dari teman, keluarga, pelanggan, serta investor.
#
# round_A= Pinjaman Series A
#
# round_B= Pinjaman Series B
#
# round_C= Pinjaman Series C
#
# round_D= Pinjaman Series D
#
# round_E= Pinjaman Series E
#
# round_F= Pinjaman Series F
#
# round_G= Pinjaman Series G
#
# round_H= Pinjaman Series H

# %% [markdown]
# ### 2. Import Package

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

#agar ketika membuka kolom jumlah maksimalnya 200 dan membuka rows jumlah maksimalnya 300
pd.set_option('display.max_columns', 200)
pd.set_option('display.max_rows', 300)
# %matplotlib inline

# %%
#untuk melihat versi dari pandas, matplotlib, dan seaborn
print('pandas version:', pd.__version__,'per September 2020')
print('matplotlib version:', matplotlib.__version__,'per September 2020')
print('seaborn version:', sns.__version__,'per September 2020')
# Out:
# pandas version: 1.0.1 per September 2020
# matplotlib version: 3.1.3 per September 2020
# seaborn version: 0.10.0 per September 2020

# %% [markdown]
# ### 3. Read Data

# %%
#untuk membaca file CSV investments_VC.csv
data = pd.read_csv('investments_VC.csv',encoding="ISO-8859-1")

# %%
# code ini berfungsi untuk memudahkan kita dalam membaca angka float
pd.set_option('display.float_format',lambda x: '%.3f' %x)

# %%
#Karena incubator hanya meminta untuk menganalisa data startup USA, data yang akan digunakan adalah data dari country code USA
data = data[data['country_code']=='USA']

# %%
data.head() # menampilkan 5 data teratas
# Out:
#                          permalink                name  \
# 0            /organization/waywire            #waywire
# 1  /organization/tv-communications  &TV Communications
# 4   /organization/r-ranch-and-mine  -R- Ranch and Mine
# 5       /organization/club-domains       .Club Domains
# 8   /organization/004-technologies    004 Technologies
#
#                         homepage_url  \
# 0             http://www.waywire.com
# 1              http://enjoyandtv.com
# 4                                NaN
# 5                   http://nic.club/
# 8  http://004gmbh.de/en/004-interact
#
#                                 category_list     market   funding_total_usd   \
# 0  |Entertainment|Politics|Social Media|News|       News           17,50,000
# 1                                     |Games|      Games           40,00,000
# 4               |Tourism|Entertainment|Games|    Tourism              60,000
# 5                                  |Software|   Software           70,00,000
# ...

# %%
#untuk mengecek informasi dari jumlah kolom, baris dan nama kolom
print("Jumlah Kolom: ",data.shape[1]) #indexing 1
print("Jumlah Baris: ",data.shape[0]) #indexing 0
print("Daftar kolom: ", data.columns)
# Out:
# Jumlah Kolom:  39
# Jumlah Baris:  28793
# Daftar kolom:  Index(['permalink', 'name', 'homepage_url', 'category_list', ' market ',
#        ' funding_total_usd ', 'status', 'country_code', 'state_code', 'region',
#        'city', 'funding_rounds', 'founded_at', 'founded_month',
#        'founded_quarter', 'founded_year', 'first_funding_at',
#        'last_funding_at', 'seed', 'venture', 'equity_crowdfunding',
#        'undisclosed', 'convertible_note', 'debt_financing', 'angel', 'grant',
#        'private_equity', 'post_ipo_equity', 'post_ipo_debt',
#        'secondary_market', 'product_crowdfunding', 'round_A', 'round_B',
#        'round_C', 'round_D', 'round_E', 'round_F', 'round_G', 'round_H'],
#       dtype='object')

# %% [markdown]
# ### 4. Describe Data

# %%
#untuk mendeskripsikan dataframe investment yang terdiri dari kolom, type data kolom, jumlah data nan, jumlah persen dari nan
#jumlah nunique, jumlah unique
data_describe =[]

for i in data.columns: #mengiterasi i di setiap kolom pada data
    data_describe.append([ #menambahkan hasil i, tipe data, jumlah NaN, persentase nan yang dibulatkan , jumlah unique, unique nya ke dalam list data_describe
        i,
        data[i].dtypes,#tipe
        data[i].isna().sum(),#jumlah NaN
        round((((data[i].isna().sum())/(len(data)))*100),2),#Persentase jumlah NaN
        data[i].nunique(),#Jumlah Unique
        data[i].unique() #Unique
    ])

# %%
 # membuat dataframe dengan data data_describe dengan kolom-kolom tersebut
DESC = pd.DataFrame(data_describe, columns=['column','type','nan','nan%','nunique','unique'])

# %%
DESC
# Out:
#                   column     type   nan   nan%  nunique  \
# 0              permalink   object     0  0.000    28792
# 1                   name   object     0  0.000    28756
# 2           homepage_url   object  2239  7.780    26486
# 3          category_list   object  1761  6.120     9637
# 4                market    object  1764  6.130      687
# 5     funding_total_usd    object     0  0.000     8638
# 6                 status   object   560  1.940        3
# 7           country_code   object     0  0.000        1
# 8             state_code   object    26  0.090       51
# 9                 region   object     0  0.000      245
# 10                  city   object    63  0.220     2304
# 11        funding_rounds  float64     0  0.000       16
# 12            founded_at   object  5097 17.700     2577
# 13         founded_month   object  5158 17.910      391
# 14       founded_quarter   object  5158 17.910      204
# 15          founded_year  float64  5158 17.910       95
# ...

# %% [markdown]
# - berdasarkan data persentase nan diatas, terdapat beberapa kolom yang memiliki Nan, sehingga perlu dilakukan pengecekan lebih detail lagi apa perlu di drop atau tidak
# - lalu berdasarkan informasi dari data total funding, isi value dr column tersebuat adalah float, tapi formatnya tidak menggunakan titik melainkan koma, sehingga diperlukan replace agar sesuai dengan format

# %%
data.describe().T
# Out:
#                          count        mean           std      min      25%  \
# funding_rounds       28793.000       1.886         1.481    1.000    1.000
# founded_year         23635.000    2006.789         8.019 1902.000 2005.000
# seed                 28793.000  237217.859   1015971.514    0.000    0.000
# venture              28793.000 9378347.793  30956179.515    0.000    0.000
# equity_crowdfunding  28793.000    6556.259    220096.156    0.000    0.000
# undisclosed          28793.000   50007.883   1246993.333    0.000    0.000
# convertible_note     28793.000   37019.312   1872656.484    0.000    0.000
# debt_financing       28793.000 2717185.001 179321418.341    0.000    0.000
# angel                28793.000   55476.445    431846.946    0.000    0.000
# grant                28793.000  202074.906   6008295.552    0.000    0.000
# private_equity       28793.000 2187050.056  36136855.279    0.000    0.000
# ...

# %% [markdown]
# - berdasarkan data diatas terlihat jelas total_funding tidak tampil, sehingga sudah jelas bahwa value dari total_funding perlu diperbaiki agar bisa ditampilkan karna data typenya adalah float

# %% [markdown]
# ### 5.Fixing Type Of Each Column

# %%
#pengecekan bentuk dan nama kolum
data.nunique()
# Out:
# permalink               28792
# name                    28756
# homepage_url            26486
# category_list            9637
#  market                   687
#  funding_total_usd       8638
# status                      3
# country_code                1
# state_code                 51
# region                    245
# city                     2304
# funding_rounds             16
# founded_at               2577
# founded_month             391
# founded_quarter           204
# founded_year               95
# first_funding_at         3529
# last_funding_at          3203
# seed                     1246
# venture                  6322
# equity_crowdfunding       148
# undisclosed               179
# convertible_note          243
# debt_financing           1691
# angel                     307
# grant                     296
# private_equity            574
# post_ipo_equity           157
# post_ipo_debt              44
# secondary_market           14
# product_crowdfunding       85
# ...

# %% [markdown]
# Dari hasil tersebut , column market dan funding_total_usd perlu dirapikan agar tidak ada spasi

# %%
#untuk merename columns market dan funding_total_usd
data.rename(columns=lambda x: x.strip(), inplace=True)
data.nunique()
# Out:
# permalink               28792
# name                    28756
# homepage_url            26486
# category_list            9637
# market                    687
# funding_total_usd        8638
# status                      3
# country_code                1
# state_code                 51
# region                    245
# city                     2304
# funding_rounds             16
# founded_at               2577
# founded_month             391
# founded_quarter           204
# founded_year               95
# first_funding_at         3529
# last_funding_at          3203
# seed                     1246
# venture                  6322
# equity_crowdfunding       148
# undisclosed               179
# convertible_note          243
# debt_financing           1691
# angel                     307
# grant                     296
# private_equity            574
# post_ipo_equity           157
# post_ipo_debt              44
# secondary_market           14
# product_crowdfunding       85
# ...

# %% [markdown]
# ### 6. Handling Missing Value

# %%
#untuk menvisualisasikan data yang akan diolah, sehingga bisa tau dimana saja letak NAnnya
plt.figure(figsize=(20,20))# untuk size
sns.heatmap(data.isna()) # untuk plot heatmap NaN
plt.show()
# plt.savefig('handling missing.png') # untuk mensave hasil plot

# %% [markdown]
# ### 7. Dropna & Fillna

# %%
# Dari pengecekan column jenis kategori, terdapat beberapa Nan, 
#karena kita tidak tahu jenis categori untuk perusahaan yang tidak memiliki categori, maka datanya akan didrop
data.dropna(subset = ['category_list'], inplace= True)
data
# Out:
#                              permalink                name  \
# 0                /organization/waywire            #waywire
# 1      /organization/tv-communications  &TV Communications
# 4       /organization/r-ranch-and-mine  -R- Ranch and Mine
# 5           /organization/club-domains       .Club Domains
# 8       /organization/004-technologies    004 Technologies
# ...                                ...                 ...
# 49426              /organization/zynga               Zynga
# 49427           /organization/zyngenia            Zyngenia
# 49429         /organization/zyomyx-inc              ZYOMYX
# 49431              /organization/zyrra               Zyrra
# 49437                  /organization/x               [x+1]
#
#                             homepage_url  \
# 0                 http://www.waywire.com
# 1                  http://enjoyandtv.com
# 4                                    NaN
# 5                       http://nic.club/
# 8      http://004gmbh.de/en/004-interact
# ...

# %%
#pengecekan juga terhadap market
data.dropna(subset= ['market'], inplace = True)
data
# Out:
#                              permalink                name  \
# 0                /organization/waywire            #waywire
# 1      /organization/tv-communications  &TV Communications
# 4       /organization/r-ranch-and-mine  -R- Ranch and Mine
# 5           /organization/club-domains       .Club Domains
# 8       /organization/004-technologies    004 Technologies
# ...                                ...                 ...
# 49426              /organization/zynga               Zynga
# 49427           /organization/zyngenia            Zyngenia
# 49429         /organization/zyomyx-inc              ZYOMYX
# 49431              /organization/zyrra               Zyrra
# 49437                  /organization/x               [x+1]
#
#                             homepage_url  \
# 0                 http://www.waywire.com
# 1                  http://enjoyandtv.com
# 4                                    NaN
# 5                       http://nic.club/
# 8      http://004gmbh.de/en/004-interact
# ...

# %%
# data pada funding total formatnya masi ada koma dan salah sehingga perlu adanya replace pada values funding total
data['funding_total_usd'] = data['funding_total_usd'].str.strip().str.replace(",","")
data['funding_total_usd'] = data['funding_total_usd'].replace("-",0).astype("float")
data
# Out:
#                              permalink                name  \
# 0                /organization/waywire            #waywire
# 1      /organization/tv-communications  &TV Communications
# 4       /organization/r-ranch-and-mine  -R- Ranch and Mine
# 5           /organization/club-domains       .Club Domains
# 8       /organization/004-technologies    004 Technologies
# ...                                ...                 ...
# 49426              /organization/zynga               Zynga
# 49427           /organization/zyngenia            Zyngenia
# 49429         /organization/zyomyx-inc              ZYOMYX
# 49431              /organization/zyrra               Zyrra
# 49437                  /organization/x               [x+1]
#
#                             homepage_url  \
# 0                 http://www.waywire.com
# 1                  http://enjoyandtv.com
# 4                                    NaN
# 5                       http://nic.club/
# 8      http://004gmbh.de/en/004-interact
# ...

# %% [markdown]
# ### Create Column First_Funding_at_Month

# %%
## Karena kita ingin mencari bulan yang paling potential dalam melakukan pitching, kita akan mengestraks bulan dr column
# first_fungding


data['first_funding_at']= pd.to_datetime(data['first_funding_at'], errors='coerce') # mengubah format object menjadi datetime

# %%
#melihat dtype dari first funding at
data['first_funding_at']
# Out:
# 0       2012-06-30
# 1       2010-06-04
# 4       2014-08-17
# 5       2013-05-31
# 8       2014-07-24
#            ...
# 49426   2007-01-01
# 49427   2010-09-09
# 49429   2010-01-29
# 49431   2010-10-21
# 49437   2008-06-01
# Name: first_funding_at, Length: 27029, dtype: datetime64[ns]

# %%
## Proses Ekstraksi
purchase_dt = data['first_funding_at'].dt

# %%
## membuat kolum bulan dari hasil ekstaksi data['first_funding_at']
data['first_funding_at_month']=purchase_dt.month_name()
data['first_funding_at_month']
# Out:
# 0             June
# 1             June
# 4           August
# 5              May
# 8             July
#            ...
# 49426      January
# 49427    September
# 49429      January
# 49431      October
# 49437         June
# Name: first_funding_at_month, Length: 27029, dtype: object

# %% [markdown]
# ### 8.  Visualisasi Data

# %%
data.head()
# Out:
#                          permalink                name  \
# 0            /organization/waywire            #waywire
# 1  /organization/tv-communications  &TV Communications
# 4   /organization/r-ranch-and-mine  -R- Ranch and Mine
# 5       /organization/club-domains       .Club Domains
# 8   /organization/004-technologies    004 Technologies
#
#                         homepage_url  \
# 0             http://www.waywire.com
# 1              http://enjoyandtv.com
# 4                                NaN
# 5                   http://nic.club/
# 8  http://004gmbh.de/en/004-interact
#
#                                 category_list      market  funding_total_usd  \
# 0  |Entertainment|Politics|Social Media|News|       News         1750000.000
# 1                                     |Games|      Games         4000000.000
# 4               |Tourism|Entertainment|Games|    Tourism           60000.000
# 5                                  |Software|   Software         7000000.000
# ...

# %% [markdown]
# ### A. Top Ten Categories Raise The Most Funds

# %%
#Categori bisnis yang paling banyak menerima funding
top_market = data.groupby('market').sum()['funding_total_usd'].sort_values(ascending=False)
print(top_market.head(10))
print('='*100)
# Out:
# market
#  Biotechnology          56111735974.000
#  Mobile                 41025868343.000
#  Software               31893512081.000
#  Health Care            26625917095.000
#  Clean Technology       25973034951.000
#  Enterprise Software    14741903356.000
#  Health and Wellness    10953467385.000
#  Advertising             9743000698.000
#  E-Commerce              9664344139.000
#  Hardware + Software     9540534989.000
# Name: funding_total_usd, dtype: float64
# ...

# %%
#untuk melakukan visualisasi data top ten categories raise the most funds
fig = plt.subplots(figsize=(20,10)) #code untuk memberikan ukuran grafik


axes = sns.barplot(data = data, x=top_market.head(10).index, y = top_market.head(10)) #code untuk menampilkan barplot
axes.set_xlabel('Category of Market') #memberi nama label pada xlabel
axes.set_ylabel('Total Funding') #memberi label pada y label
axes.set_title('Top ten categories raise the most funds ') #memberi nama title dari grafic
plt.show() # untuk menghilangkan format tulisan ketika menampilkan grafik

# %% [markdown]
# ### B.Top Ten Total Category of Market

# %%
jumlah_market = data['market'].value_counts()
print(jumlah_market.head(10)) 
print('='*100)

#untuk melakukan visualisasi data top ten total category of market
fig = plt.subplots(figsize=(20,10)) #code untuk memberikan ukuran grafik
axes = sns.barplot(data = data, x=jumlah_market.head(10).index, y = jumlah_market.head(10).values) #untuk menampilkan bar plot
axes.set_xlabel('Category of Market') #untuk menampilkan x label
axes.set_ylabel('Total startup in category of market ') # untuk menampilkan y label
axes.set_title('Top Ten Total Category of Market ') #untuk menampilkan judul grafik
plt.show() # untuk menghilangkan format tulisan ketika menampilkan grafik
# Out:
#  Software                2962
#  Biotechnology           2716
#  Mobile                  1032
#  Curated Web              941
#  Health Care              915
#  Enterprise Software      859
#  E-Commerce               757
#  Health and Wellness      731
#  Clean Technology         710
#  Hardware + Software      697
# Name: market, dtype: int64
# ...

# %% [markdown]
# #untuk melihat rasio persen dari total start up
# jumlah_market = data['market'].value_counts()
# print((jumlah_market.head(10)/sum(jumlah_market.head(10)))*100)

# %%
#melakukan grouping data market menggunakan crosstab
mt= pd.crosstab(index=data['market'], columns= 'jumlah')
tes =mt.sort_values(by='jumlah', ascending=False)
market_tinggi =tes.reset_index()
# print(market_tinggi) (ini buat ambil index labelnya)   , terus ini buat pie nya 

#melakukan visualisasi dari top ten of market
figgg = plt.subplots(figsize=(12,9))
plt.pie(jumlah_market.head(10) , labels=market_tinggi['market'].head(10), #code untuk menampilkan grafik pie bar
        startangle=0,
        textprops = {
            'size' : 10,
            'color' : 'black'
        },
        autopct='%1.0f%%')       #untuk menampilkan percentage
plt.show()

# %%
# mt= pd.crosstab(index=data['market'], columns= 'jumlah')
# tes =mt.sort_values(by='jumlah', ascending=False)
# market_tinggi =tes.reset_index()

# show_data_market = data['market'].value_counts('funding_total_usd',ascending=False)
# market_group = show_data_market.head(10)

# import plotly.express as px
# fig = px.pie(values=market_group, names=market_tinggi['market'].head(10))
# # fig.write_image("fig1.jpeg") #untuk save png
# fig.show()

# %% [markdown]
# ### C. Top Month

# %%
#Bulan yang potensial untuk melakukan pitching pertama
# pd.pivot_table(USA,columns=['first_funding_at_month'],margins=True)
top_month = data['first_funding_at_month'].value_counts()
# print(top_month)
print((top_month.head(12)/sum(top_month.head(12)))*100)
# print('='*100)
# Out:
# January     13.209
# August       8.791
# June         8.761
# October      8.610
# September    8.517
# March        8.155
# April        8.092
# July         8.077
# May          7.829
# November     6.782
# February     6.638
# December     6.541
# Name: first_funding_at_month, dtype: float64

# %%
#untuk melihat variasi data dari kolom first_funding_at_month
data['first_funding_at_month'].unique()
# Out:
# array(['June', 'August', 'May', 'July', 'April', 'March', 'January',
#        'October', 'November', 'February', 'September', 'December', nan],
#       dtype=object)

# %%
#untuk melihat data Nan
data['first_funding_at_month'].isna().sum()
# Out:
# 1

# %%
#untuk mendrop data nan
data['first_funding_at_month'].dropna(inplace=True)

# %%
#visualisasi data top month
fig_month = plt.subplots(figsize=(20,10))
axes2 = sns.barplot(data = data, x=top_month.head(10).index, y = top_month.head(10).values) #untuk menampilkan barplot
axes2.set_xlabel('month')
axes2.set_ylabel('total Startup')
axes2.set_title('Top Month ')
plt.show()

# %% [markdown]
# ###  D. Outliers :

# %%
data.describe()['funding_total_usd']
# Out:
# count         27029.000
# mean       16659400.016
# std       197177800.859
# min               0.000
# 25%          186200.000
# 50%         1975000.000
# 75%        10041500.000
# max     30079503000.000
# Name: funding_total_usd, dtype: float64

# %%
#untuk mendefine Q3 danQ1 dari funding total usd
Q3_funding = data.describe()['funding_total_usd']['75%']
Q1_funding = data.describe()['funding_total_usd']['25%']

# %%
#untuk mencari IQR dari funding total usd
IQR = Q3_funding-Q1_funding

IQR
# Out:
# 9855300.0

# %% [markdown]
# IQR = Q3-Q1

# %%
#untuk mencari upper fence
UpperFence = Q3_funding + (1.5*IQR)

UpperFence
# Out:
# 24824450.0

# %%
#untuk mencari lower fence
LowerFence = Q1_funding - (1.5*IQR)

LowerFence
# Out:
# -14596750.0

# %%
#untuk menampilkan data outlier
Outliers = data[(data['funding_total_usd'] < LowerFence) | (data['funding_total_usd'] > UpperFence)]

Outliers.sort_values(by= 'funding_total_usd', ascending=False).head()
# Out:
#                                   permalink                    name  \
# 45815                 /organization/verizon  Verizon Communications
# 8664                /organization/clearwire               Clearwire
# 15315  /organization/first-data-corporation  First Data Corporation
# 38289               /organization/sigmacare               sigmacare
# 14705                /organization/facebook                Facebook
#
#                                             homepage_url  \
# 45815  http://www.verizon.com/?lid=//global//residential
# 8664                            http://www.clearwire.com
# 15315                           http://www.firstdata.com
# 38289                               http://sigmacare.com
# 14705                                http://facebook.com
#
#                                            category_list  \
# 45815                                           |Mobile|
# 8664                                   |Internet|Mobile|
# ...

# %%
#menampilkan boxplot dari funding_total_usd
plt.boxplot(Outliers['funding_total_usd'])
plt.show()
